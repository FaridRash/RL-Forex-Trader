# %% [markdown]
# <a href="https://colab.research.google.com/github/FaridRash/RL-Forex-Trader/blob/main/Notebook_1st.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
# !git clone https://github.com/FaridRash/RL-Forex-Trader
# Out:
# fatal: destination path 'RL-Forex-Trader' already exists and is not an empty directory.

# %%
df_raw = pd.read_csv('/content/RL-Forex-Trader/EURUSD-2000-2020-15m.csv')

# %%
df = df_raw.drop(columns=['DATE_TIME'])
df.insert(0, 'Candle_num', range(1, len(df) + 1))

# %%
def EMA(df, base, target, period, alpha=False):
    con = pd.concat([df[:period][base].rolling(window=period).mean(), df[period:][base]])

    if alpha == True:
      # (1 - alpha) * previous_val + alpha * current_val
      df[target] = con.ewm(alpha=1/period, adjust=False).mean()
    else:
      # alpha * current_val + (1 - alpha) * previous_val
      df[target] = con.ewm(span=period, adjust=False).mean()

    return df

# %%
df = EMA(df, 'CLOSE', 'EMA_20', 20)

df = df.drop(index=range(0,19))
df = df.reset_index(drop=True)
df.insert(0, 'Candle_number', range(1, len(df) + 1))
df = df.drop(columns=['Candle_num'])
df['MA_Delta'] = df['CLOSE'] - df['EMA_20']

# %%
df
# Out:
#         Candle_number     HIGH      LOW     OPEN    CLOSE    EMA_20  MA_Delta
# 0                   1  1.01710  1.01660  1.01670  1.01670  1.014385  0.002315
# 1                   2  1.01710  1.01650  1.01710  1.01650  1.014586  0.001914
# 2                   3  1.01710  1.01640  1.01710  1.01670  1.014788  0.001912
# 3                   4  1.01680  1.01650  1.01680  1.01670  1.014970  0.001730
# 4                   5  1.01720  1.01660  1.01660  1.01690  1.015154  0.001746
# ...               ...      ...      ...      ...      ...       ...       ...
# 500727         500728  1.09007  1.08790  1.08803  1.08895  1.090554 -0.001604
# 500728         500729  1.08936  1.08807  1.08895  1.08872  1.090379 -0.001659
# 500729         500730  1.09118  1.08853  1.08872  1.09086  1.090425  0.000435
# 500730         500731  1.09086  1.08946  1.09086  1.08970  1.090356 -0.000656
# 500731         500732  1.09060  1.08953  1.08974  1.08965  1.090289 -0.000639
#
# [500732 rows x 7 columns]
